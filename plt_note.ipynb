# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
x = np.linspace(0,10,500)
y = np.cumsum(np.random.randn(500,6),axis=0)

# plt.style.use("ggplot")
plt.plot(x,y)
plt.legend(["a","bill","c","d","e","f"],ncol=2, loc="upper left")
plt.show()

# %%
x = np.random.randint(100,size=10)
y = np.sin(x)

ax1 = plt.axes()
ax2 = plt.axes([0.68, 0.65, 0.2, 0.2])
ax1.bar(x, y)
ax2.hist(x)
# Out:
# (array([2., 0., 0., 2., 1., 1., 2., 0., 1., 1.]),
#  array([ 1. , 10.5, 20. , 29.5, 39. , 48.5, 58. , 67.5, 77. , 86.5, 96. ]),
#  <a list of 10 Patch objects>)

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.4], xticklabels=[],ylim=(-1.2,1.2))
ax3 = fig.add_axes([0.3, 0.6, 0.4, 0.1], xticklabels=[],ylim=(-1.2,1.2))
ax2 = fig.add_axes([0.1, 0.8, 0.4, 0.1], xticklabels=[], ylim=(-1.2, 1.2))

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4], xticklabels=[],ylim=(-1.2,1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4], ylim=(-1.2,1.2))

x = np.linspace(0,10, num=100)
print(x)
ax1.plot(x, np.sin(x))
ax2.plot(x, np.cos(x))
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
fig = plt.figure()
# 可調整子圖之間彼此的間距
fig.subplots_adjust(hspace=1, wspace=1)
nrow = 2
ncol = 3
for order in range(6):
    plt.subplot(nrow, ncol, order + 1)
    plt.text(0.5,0.5,f"{nrow, ncol, order + 1}",fontsize=12,ha="center")
plt.show()

# %%
nrow = 2
ncol = 3

# 注意此處sharex="col"及sharey="row"不可以把"col"跟"row"交換喔，不然會沒效果~~
fig, ax = plt.subplots(nrow, ncol, sharex="col", sharey="row")

print("=====我是分隔線")
print(type(ax))
print(ax)
print("=====我是分隔線")

# 注意此處沒有給大畫布(plt.figure)，故沒有subplot_adjust此性質。
# fig.subplot_adjust(hspace=0.4, wspace=0.4)

for row in range(2):
    for col in range(3):
        ax[row, col].text(0.5, 0.5, f"{row, col}", ha="center")
        ax[row, col].set_title(f"{row, col}")
        
plt.show()
# Out:
# =====我是分隔線
# <class 'numpy.ndarray'>
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020193022C88>
# ...
# =====我是分隔線

# %%
nrow = 2
ncol = 3

# GridSpec只是個interface的作用，它並不會自動產生圖出來
grid = plt.GridSpec(nrow, ncol, hspace=0.4, wspace=0.4)

plt.subplot(grid[0,0])
plt.subplot(grid[0,1:])
plt.subplot(grid[1,1])
plt.subplot(grid[1,2:])

# %%
# example
mean = [0,0]
cov = [[1,1],[1,2]]

rng = np.random.RandomState(0)
x, y = rng.multivariate_normal(mean, cov, 100).T

nrow = 4
ncol = 4
fig = plt.figure(figsize=(8,8))
grid = plt.GridSpec(nrow, ncol, hspace=0.4, wspace=0.4)

main_ax = fig.add_subplot(grid[:-1,1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[],sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], sharex=main_ax)

main_ax.plot(x, y, "ok", markersize=5)
y_hist.hist(y, bins=40, histtype="stepfilled", orientation="horizontal", color="gray")
y_hist.invert_xaxis()
x_hist.hist(x, bins=40, histtype="stepfilled", color="gray")
x_hist.invert_yaxis()

# %%
import pandas as pd
import seaborn as sns

dict_ = {
    "country":["Taiwan","China","China","China","Taiwan"],
    "continent":["Asia","Asia","Asia","Asia","Asia"],
    "Year":[1992,1960,1988,1990,1943],
    "Life_Exp":[28.80,30.33,31.99,34.02,36.08],
    "pop":[8400500,9876543,10765431,11234567,12987650],
    "GDP_per_CAP":[779.44,820.53,853.10,836.19,739.98]
}


df = pd.DataFrame(dict_)

sns.pairplot(df)
plt.show()

# %%
df["popLog"] = np.log10(df["pop"])
df["GDP_per_CAP_Log"] = np.log10(df["GDP_per_CAP"])
df = df.drop(["pop", "GDP_per_CAP"], axis=1)
df
# Out:
#   country continent  Year  Life_Exp    popLog  GDP_per_CAP_Log
# 0  Taiwan      Asia  1992     28.80  6.924305         2.891783
# 1   China      Asia  1960     30.33  6.994605         2.914094
# 2   China      Asia  1988     31.99  7.032031         2.931000
# 3   China      Asia  1990     34.02  7.050556         2.922305
# 4  Taiwan      Asia  1943     36.08  7.113531         2.869220

# %%
sns.pairplot(df, hue="country", diag_kind="hist")
plt.show()

# %%
sns.pairplot(df, vars=["Year", "Life_Exp"],hue="country", diag_kind="kde")

print("=====我是分隔線=====")
print(["Look Scatter and hist"] * 2)
print("=====我是分隔線=====")

plt.suptitle("\n".join(["Look Scatter and hist"] * 2 ), fontsize=28, y=1.2)
plt.show()
# Out:
# =====我是分隔線=====
# ['Look Scatter and hist', 'Look Scatter and hist']
# =====我是分隔線=====

# %%
grid = sns.PairGrid(df, vars=["Year", "Life_Exp"])
grid.map_upper(plt.scatter, color="red")
grid.map_lower(sns.kdeplot, cmap="Blues")
grid.map_diag(plt.hist, bins=20, color="yellow", edgecolor="k")

# %%
def Corr(x, y, **kwargs):
    corr = np.corrcoef(x, y)[0, 1]
    
    mark = r"$\rho$ = {:.2f}".format(corr)
    
    # 取得當前axes
    ax = plt.gca()
    
    # 為啥這段要加 xycoords才會顯示出圖來?
    ax.annotate(mark, xy=(0.3, 1), fontsize=20, xycoords = ax.transAxes)

def Describe(col, **kwargs):
    
    # Statistics
    mean = np.mean(col)
    max = np.max(col)
    min = np.min(col)
    Q50 = np.quantile(col, q=0.5)
    std = np.std(col)
    
    # text
    mark = f'''
        mean : {mean:.2f}
        std  : {std:.2f}
        max  : {max:.2f}
        min  : {min:.2f}
        Q50  : {Q50:.2f}
    '''   
    
    # 取得當前axes
    ax = plt.gca()
    ax.annotate(mark, xy=(0.1, 0.1), fontsize=12, xycoords = ax.transAxes)

grid = sns.PairGrid(df, vars=["Life_Exp", "popLog", "GDP_per_CAP_Log"])
grid.map_upper(plt.scatter, color="red")
grid.map_upper(Corr)
grid.map_lower(sns.kdeplot, cmap="YlGnBu")
grid.map_diag(Describe) # 怎取得欄位名稱?

# %%
mean, cov = [1,0], [[5,0],[0,1]]

# # way1
# x, y = np.random.multivariate_normal(mean, cov, size=500).T
# plt.hist(x, alpha=0.2)
# plt.hist(y, alpha=0.2)

# way2
import pandas as pd
data = np.random.multivariate_normal(mean, cov, size=500)
df = pd.DataFrame(data, columns=["x","y"])

for i in "xy":
    sns.distplot(df[i])
    sns.kdeplot(df[i], alpha=0.2, shade=True)

plt.show()

# %%
with sns.axes_style("white"):
    sns.jointplot(df["x"], df["y"], kind="kde")
with sns.axes_style("white"):
    sns.jointplot(df["x"], df["y"], kind="hex")

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris, hue="species")
plt.show()

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips["tip_pct"] = tips["tip"] * 100 / tips["total_bill"]

with sns.axes_style("white"):
    grid = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
    grid.map(plt.hist, "tip_pct", bins=np.linspace(0,100,50))

with sns.axes_style("ticks"):
    ax = sns.factorplot("day", "tip_pct", "sex", data=tips, kind="box")
    ax.set_axis_labels("day", "tip_pct")
    
with sns.axes_style("white"):
    sns.jointplot("total_bill", "tip", data=tips, kind="hex")
    
sns.jointplot("total_bill", "tip", data=tips, kind="reg")
# Out:
# C:\Users\gn026\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
planets = sns.load_dataset("planets")
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
with sns.axes_style("white"):
    ax = sns.factorplot("year", data=planets, kind="count", hue="method", order=range(2001,2015), aspect=2.0)
    ax.set_xlabels("Year")
    ax.set_ylabels("Number of Planets Discovered")
